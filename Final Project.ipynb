# %% [markdown]
# ## Final Project
# link to the website: https://www.kaggle.com/mohansacharya/graduate-admissions

# %% [markdown]
# Part 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Admission_Predict.csv',index_col='Serial No.')
data
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# 6                 330          115                  5  4.5   3.0  9.34
# 7                 321          109                  3  3.0   4.0  8.20
# 8                 308          101                  2  3.0   4.0  7.90
# 9                 302          102                  1  2.0   1.5  8.00
# 10                323          108                  3  3.5   3.0  8.60
# 11                325          106                  3  3.5   4.0  8.40
# 12                327          111                  4  4.0   4.5  9.00
# ...

# %%
data.dropna()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# 6                 330          115                  5  4.5   3.0  9.34
# 7                 321          109                  3  3.0   4.0  8.20
# 8                 308          101                  2  3.0   4.0  7.90
# 9                 302          102                  1  2.0   1.5  8.00
# 10                323          108                  3  3.5   3.0  8.60
# 11                325          106                  3  3.5   4.0  8.40
# 12                327          111                  4  4.0   4.5  9.00
# ...

# %% [markdown]
# Part 2

# %%
data.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
data["GRE Score"].mean()
# the mean GRE Score of 500 candidates is 316.472
# Out:
# 316.472

# %%
data.loc[data["Research"]==1]["GRE Score"].mean()
# candidates having research experience have mean GRE Score higher than total average
# Out:
# 322.10714285714283

# %% [markdown]
# Part 3

# %%
data.groupby('University Rating').mean()
# as University Rating gets higher, means of all columns get higher
# Out:
#                     GRE Score  TOEFL Score       SOP      LOR       CGPA  \
# University Rating
# 1                  304.911765   100.205882  1.941176  2.426471  7.798529
# 2                  309.134921   103.444444  2.682540  2.956349  8.177778
# 3                  315.030864   106.314815  3.308642  3.401235  8.500123
# 4                  323.304762   110.961905  4.000000  3.947619  8.936667
# 5                  327.890411   113.438356  4.479452  4.404110  9.278082
#
#                    Research  Chance of Admit
# University Rating
# 1                  0.294118          0.562059
# 2                  0.293651          0.626111
# 3                  0.537037          0.702901
# 4                  0.780952          0.801619
# 5                  0.876712          0.888082

# %%
data.pivot_table(values='CGPA',aggfunc=np.mean,index='TOEFL Score')
# Out:
#                  CGPA
# TOEFL Score
# 92           7.880000
# 93           7.280000
# 94           7.735000
# 95           7.800000
# 96           7.723333
# 97           7.727143
# 98           7.827000
# 99           7.874348
# 100          8.085000
# 101          8.093000
# 102          8.280833
# 103          8.318400
# 104          8.323793
# 105          8.219189
# 106          8.339286
# 107          8.497143
# 108          8.626316
# 109          8.744737
# 110          8.776136
# 111          8.953500
# 112          8.983929
# 113          9.121579
# 114          9.152222
# 115          9.270909
# 116          9.288750
# 117          9.495000
# 118          9.470000
# 119          9.536000
# 120          9.565556

# %% [markdown]
# Part 4

# %%
plt.plot(data['GRE Score'],data['Chance of Admit '],'o')
plt.title('Relationship between GRE Score and Chance of Admission to Graduate School')
plt.xlabel('GRE Score')
plt.ylabel('Chance of Admit')
# it shows a strong positive correlation between GRE Score and Chance of Admission 
# can use it to give advice about graduate school application preparation
# Out:
# Text(0, 0.5, 'Chance of Admit')

# %% [markdown]
# Part 6
# supervised learning using linear regression

# %%
import sklearn

X = data.drop('Chance of Admit ', axis =1) 
y = pd.DataFrame(data['Chance of Admit '])

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
preds = reg.predict(X_test)
preds
# Out:
# array([[0.72708531],
#        [0.96108359],
#        [0.93938174],
#        [0.49879932],
#        [0.6282753 ],
#        [0.60977889],
#        [0.82877401],
#        [0.73852339],
#        [1.00189524],
#        [0.57890696],
#        [0.7212335 ],
#        [0.74326288],
#        [0.57341332],
#        [0.88506928],
#        [0.85018156],
#        [0.64600186],
#        [0.52344288],
#        [0.74907429],
#        [0.83668191],
#        [0.95337409],
#        [0.58252811],
#        [0.7852536 ],
#        [0.63219817],
#        [0.66739489],
#        [0.72011089],
#        [0.78115903],
#        [0.6813449 ],
#        [0.49079092],
#        [0.65358137],
#        [0.51869687],
#        [0.61958968],
#        [0.69896371],
#        [0.84981201],
#        [0.75926721],
#        [0.90464508],
#        [0.70306792],
#        [0.83743444],
#        [0.83388839],
#        [0.58744872],
#        [0.70704041],
#        [0.60846447],
#        [0.55737152],
#        [0.758117  ],
# ...

# %%
reg.score(X_test,y_test)
# Out:
# 0.8297825903467436

# %%
reg.score(X_train,y_train)
# Out:
# 0.8168660200237327

# %%
reg.coef_
# Out:
# array([[0.00250671, 0.0019535 , 0.00728106, 0.00052363, 0.01915651,
#         0.11466523, 0.0164309 ]])

# %%
X.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research'],
#       dtype='object')

# %% [markdown]
# this analysis suggests that all listed factors in column names affect Chance of Admit to graduate school. Among these factors, CGPA is the most significant. So when it comes to preparing for application, these factors should all be taken into account according to their relative importance.
